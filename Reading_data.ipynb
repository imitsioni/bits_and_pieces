# %%
import numpy as np
import os
import fnmatch
from sys import stdout

# %%
'''
* Parses data from the inv_damp controller.
* The different features are returned separately in dictionary form {dataset_id: data}.
*
@param monster: is the concatenation of all datasets and all features and can be used for
fitting scaler.
'''

def create_datasets(filepath, verbose = 0):
    """
    The final dataset will contain all the sub-datasets collected. Given the
    directory they are in, all txt files (forces and positions for now) will
    be located and executed.
    """
    # Get a list of the various txt files
    listOfPositionFiles = [] # actual cartesian position
    listOfForceFiles = [] # sensor forces
    listOfInputFiles = [] # f_ref "forces"

    monster_positions = np.empty((1,3))
    monster_forces = np.empty((1,3))
    monster_inputs = np.empty((1,3))

    force_data = {}
    position_data = {}
    input_data = {}

    for (dirpath, dirnames, filenames) in os.walk(filepath):
        dirnames.sort()

        for txtname in fnmatch.filter(filenames, 'positions.txt'):
            listOfPositionFiles.append(os.path.join(dirpath, txtname))

        for txtname in fnmatch.filter(filenames, 'forces.txt'):
            listOfForceFiles.append(os.path.join(dirpath, txtname))

        for txtname in fnmatch.filter(filenames, 'f_ref.txt'):
            listOfInputFiles.append(os.path.join(dirpath, txtname))

    
    print("Retrieved %d position files, %d force files and %d input files from base directory '%s' "
                     %(len(listOfPositionFiles), len(listOfForceFiles), len(listOfInputFiles), filepath))
    if verbose:
        for i in range(len(listOfPositionFiles)):
            print("%d %s  %s %s \n" %(i, listOfPositionFiles[i], listOfForceFiles[i], listOfInputFiles[i]))

    # Read the appropriate columns and parse them into np arrays
    for file_idx, filename in enumerate(listOfForceFiles):
        time, seq, f_x, f_y, f_z, t_x, t_y, t_z = np.loadtxt(filename, usecols = (0, 1, 4, 5, 6, 7, 8, 9), skiprows = 1, delimiter = ',', unpack = True)
        f_x = f_x.reshape(-1,1)
        f_y = f_y.reshape(-1,1)
        f_z = f_z.reshape(-1,1)
        forces = np.concatenate((f_x, f_y, f_z), axis = 1)
        force_data.update({file_idx : forces})
        monster_forces = np.append(monster_forces, forces, axis = 0)

    monster_forces = monster_forces[1:,] # Remove the first "trash" line that was created with np.empty

    for file_idx, filename in enumerate(listOfPositionFiles):
        time, seq, p_x, p_y, p_z = np.loadtxt(filename, usecols = (0, 1, 4, 5, 6), skiprows = 1, delimiter = ',', unpack = True)
        p_x = p_x.reshape(-1,1)
        p_y = p_y.reshape(-1,1)
        p_z = p_z.reshape(-1,1)
        positions = np.concatenate((p_x, p_y, p_z), axis = 1)
        position_data.update({file_idx : positions})
        monster_positions = np.append(monster_positions, positions, axis = 0)

    monster_positions = monster_positions[1:,] # remove the first "trash" line that was created with np.empty


    for file_idx, filename in enumerate(listOfInputFiles):
        time, seq, f_ref_x, f_ref_y, f_ref_z = np.loadtxt(filename, usecols = (0, 1, 4, 5, 6), skiprows = 1, delimiter = ',', unpack = True)
        f_ref_x = f_ref_x.reshape(-1,1)
        f_ref_y = f_ref_y.reshape(-1,1)
        f_ref_z = f_ref_z.reshape(-1,1)
        inputs = np.concatenate((f_ref_x, f_ref_y, f_ref_z), axis = 1)
        input_data.update({file_idx : inputs})
        monster_inputs = np.append(monster_inputs, inputs, axis = 0)

    monster_inputs = monster_inputs[1:,] # remove the first "trash" line that was created with np.empty

    stupid_files = 0
    for i in range(len(position_data)):
        if len(position_data[i]) == len(force_data[i]) and len(force_data[i]) == len(input_data[i]):
            if verbose:
                print(i, position_data[i].shape, force_data[i].shape, input_data[i].shape)
        else:
            stupid_files += 1
            print("In dataset %s there is a size mismatch. Pos : %d F_s %d F_ref %d " %(listOfPositionFiles[i], position_data[i].shape[0], force_data[i].shape[0], input_data[i].shape[0]))
    print("%d files need to be fixed" %stupid_files)

    monster = np.concatenate((monster_positions, monster_forces, monster_inputs), axis = 1)

    return position_data, force_data, input_data, monster

# %%
def reset_dataset(position_data, force_data, f_ref_data):
    combined_dict = {}
    for dataset_id in position_data.keys():
        combined_dict.update({dataset_id : np.concatenate((position_data[dataset_id], force_data[dataset_id], f_ref_data[dataset_id]), axis = 1)})
    return combined_dict

# %%
"""
ATTENTION SUMMONER! Don't forget to change the path to the data!
"""

path = "Envs/bananaenv/scripts/inv_damp_data/25_04"
position_data, force_data, input_data, monster = create_datasets(path, verbose = 1)
# Out:
# Retrieved 40 position files, 40 force files and 40 input files from base directory 'Envs/bananaenv/scripts/inv_damp_data/25_04'
# 0 Envs/bananaenv/scripts/inv_damp_data/25_04/1/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/1/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/1/f_ref.txt
#
# 1 Envs/bananaenv/scripts/inv_damp_data/25_04/10/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/10/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/10/f_ref.txt
#
# 2 Envs/bananaenv/scripts/inv_damp_data/25_04/11/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/11/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/11/f_ref.txt
#
# 3 Envs/bananaenv/scripts/inv_damp_data/25_04/12/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/12/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/12/f_ref.txt
#
# 4 Envs/bananaenv/scripts/inv_damp_data/25_04/13/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/13/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/13/f_ref.txt
#
# 5 Envs/bananaenv/scripts/inv_damp_data/25_04/14/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/14/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/14/f_ref.txt
#
# 6 Envs/bananaenv/scripts/inv_damp_data/25_04/15/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/15/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/15/f_ref.txt
#
# 7 Envs/bananaenv/scripts/inv_damp_data/25_04/16/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/16/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/16/f_ref.txt
#
# 8 Envs/bananaenv/scripts/inv_damp_data/25_04/17/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/17/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/17/f_ref.txt
#
# 9 Envs/bananaenv/scripts/inv_damp_data/25_04/18/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/18/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/18/f_ref.txt
#
# 10 Envs/bananaenv/scripts/inv_damp_data/25_04/19/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/19/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/19/f_ref.txt
#
# 11 Envs/bananaenv/scripts/inv_damp_data/25_04/2/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/2/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/2/f_ref.txt
#
# 12 Envs/bananaenv/scripts/inv_damp_data/25_04/20/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/20/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/20/f_ref.txt
#
# 13 Envs/bananaenv/scripts/inv_damp_data/25_04/21/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/21/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/21/f_ref.txt
#
# 14 Envs/bananaenv/scripts/inv_damp_data/25_04/22/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/22/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/22/f_ref.txt
#
# 15 Envs/bananaenv/scripts/inv_damp_data/25_04/23/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/23/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/23/f_ref.txt
#
# 16 Envs/bananaenv/scripts/inv_damp_data/25_04/24/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/24/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/24/f_ref.txt
#
# 17 Envs/bananaenv/scripts/inv_damp_data/25_04/25/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/25/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/25/f_ref.txt
#
# 18 Envs/bananaenv/scripts/inv_damp_data/25_04/26/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/26/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/26/f_ref.txt
#
# 19 Envs/bananaenv/scripts/inv_damp_data/25_04/27/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/27/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/27/f_ref.txt
#
# 20 Envs/bananaenv/scripts/inv_damp_data/25_04/28/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/28/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/28/f_ref.txt
#
# 21 Envs/bananaenv/scripts/inv_damp_data/25_04/29/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/29/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/29/f_ref.txt
#
# 22 Envs/bananaenv/scripts/inv_damp_data/25_04/3/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/3/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/3/f_ref.txt
#
# 23 Envs/bananaenv/scripts/inv_damp_data/25_04/30/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/30/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/30/f_ref.txt
#
# 24 Envs/bananaenv/scripts/inv_damp_data/25_04/32/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/32/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/32/f_ref.txt
#
# 25 Envs/bananaenv/scripts/inv_damp_data/25_04/33/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/33/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/33/f_ref.txt
#
# 26 Envs/bananaenv/scripts/inv_damp_data/25_04/34/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/34/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/34/f_ref.txt
#
# 27 Envs/bananaenv/scripts/inv_damp_data/25_04/35/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/35/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/35/f_ref.txt
#
# 28 Envs/bananaenv/scripts/inv_damp_data/25_04/36/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/36/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/36/f_ref.txt
#
# 29 Envs/bananaenv/scripts/inv_damp_data/25_04/37/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/37/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/37/f_ref.txt
#
# 30 Envs/bananaenv/scripts/inv_damp_data/25_04/38/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/38/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/38/f_ref.txt
#
# 31 Envs/bananaenv/scripts/inv_damp_data/25_04/39/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/39/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/39/f_ref.txt
#
# 32 Envs/bananaenv/scripts/inv_damp_data/25_04/4/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/4/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/4/f_ref.txt
#
# 33 Envs/bananaenv/scripts/inv_damp_data/25_04/40/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/40/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/40/f_ref.txt
#
# 34 Envs/bananaenv/scripts/inv_damp_data/25_04/41/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/41/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/41/f_ref.txt
#
# 35 Envs/bananaenv/scripts/inv_damp_data/25_04/5/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/5/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/5/f_ref.txt
#
# 36 Envs/bananaenv/scripts/inv_damp_data/25_04/6/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/6/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/6/f_ref.txt
#
# 37 Envs/bananaenv/scripts/inv_damp_data/25_04/7/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/7/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/7/f_ref.txt
#
# 38 Envs/bananaenv/scripts/inv_damp_data/25_04/8/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/8/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/8/f_ref.txt
#
# 39 Envs/bananaenv/scripts/inv_damp_data/25_04/9/positions.txt  Envs/bananaenv/scripts/inv_damp_data/25_04/9/forces.txt Envs/bananaenv/scripts/inv_damp_data/25_04/9/f_ref.txt
#
# 0 (5636, 3) (5636, 3) (5636, 3)
# 1 (5045, 3) (5045, 3) (5045, 3)
# 2 (9200, 3) (9200, 3) (9200, 3)
# 3 (7886, 3) (7886, 3) (7886, 3)
# 4 (3998, 3) (3998, 3) (3998, 3)
# 5 (9489, 3) (9489, 3) (9489, 3)
# 6 (9707, 3) (9707, 3) (9707, 3)
# 7 (5825, 3) (5825, 3) (5825, 3)
# 8 (8227, 3) (8227, 3) (8227, 3)
# 9 (6533, 3) (6533, 3) (6533, 3)
# 10 (6236, 3) (6236, 3) (6236, 3)
# 11 (8193, 3) (8193, 3) (8193, 3)
# 12 (7901, 3) (7901, 3) (7901, 3)
# 13 (2818, 3) (2818, 3) (2818, 3)
# 14 (4706, 3) (4706, 3) (4706, 3)
# 15 (4997, 3) (4997, 3) (4997, 3)
# 16 (5550, 3) (5550, 3) (5550, 3)
# 17 (3047, 3) (3047, 3) (3047, 3)
# 18 (6028, 3) (6028, 3) (6028, 3)
# 19 (3719, 3) (3719, 3) (3719, 3)
# 20 (3329, 3) (3329, 3) (3329, 3)
# 21 (3288, 3) (3288, 3) (3288, 3)
# 22 (9414, 3) (9414, 3) (9414, 3)
# 23 (2584, 3) (2584, 3) (2584, 3)
# 24 (4249, 3) (4249, 3) (4249, 3)
# 25 (5501, 3) (5501, 3) (5501, 3)
# 26 (5167, 3) (5167, 3) (5167, 3)
# 27 (6389, 3) (6389, 3) (6389, 3)
# 28 (2700, 3) (2700, 3) (2700, 3)
# 29 (2245, 3) (2245, 3) (2245, 3)
# 30 (2702, 3) (2702, 3) (2702, 3)
# 31 (4266, 3) (4266, 3) (4266, 3)
# 32 (5384, 3) (5384, 3) (5384, 3)
# 33 (5334, 3) (5334, 3) (5334, 3)
# 34 (7197, 3) (7197, 3) (7197, 3)
# 35 (4185, 3) (4185, 3) (4185, 3)
# 36 (4504, 3) (4504, 3) (4504, 3)
# 37 (5894, 3) (5894, 3) (5894, 3)
# 38 (5076, 3) (5076, 3) (5076, 3)
# 39 (5277, 3) (5277, 3) (5277, 3)
# 0 files need to be fixed

# %%
'''
One way of iterating through datasets is by their key-values
'''
combined_dictionary = reset_dataset(position_data, force_data, input_data)
for d_idx, dataset in combined_dictionary.items():
    print("Dataset %d has length %d"%(d_idx+1, len(dataset)))
# Out:
# Dataset 1 has length 5636
# Dataset 2 has length 5045
# Dataset 3 has length 9200
# Dataset 4 has length 7886
# Dataset 5 has length 3998
# Dataset 6 has length 9489
# Dataset 7 has length 9707
# Dataset 8 has length 5825
# Dataset 9 has length 8227
# Dataset 10 has length 6533
# Dataset 11 has length 6236
# Dataset 12 has length 8193
# Dataset 13 has length 7901
# Dataset 14 has length 2818
# Dataset 15 has length 4706
# Dataset 16 has length 4997
# Dataset 17 has length 5550
# Dataset 18 has length 3047
# Dataset 19 has length 6028
# Dataset 20 has length 3719
# Dataset 21 has length 3329
# Dataset 22 has length 3288
# Dataset 23 has length 9414
# Dataset 24 has length 2584
# Dataset 25 has length 4249
# Dataset 26 has length 5501
# Dataset 27 has length 5167
# Dataset 28 has length 6389
# Dataset 29 has length 2700
# Dataset 30 has length 2245
# Dataset 31 has length 2702
# Dataset 32 has length 4266
# Dataset 33 has length 5384
# Dataset 34 has length 5334
# Dataset 35 has length 7197
# Dataset 36 has length 4185
# Dataset 37 has length 4504
# Dataset 38 has length 5894
# Dataset 39 has length 5076
# Dataset 40 has length 5277
